# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import os
from prophet import Prophet
import pandas as pd

# %%
time = ['2023-09-01', '2023-09-02','2023-09-03','2023-09-04','2023-09-05','2023-09-06','2023-09-07','2023-09-08','2023-09-09','2023-09-10','2023-09-11','2023-09-12','2023-09-13','2023-09-14','2023-09-15','2023-09-16','2023-09-17','2023-09-18','2023-09-19','2023-09-20','2023-09-21','2023-09-22','2023-09-23','2023-09-24','2023-09-25','2023-09-26','2023-09-27','2023-09-28','2023-09-29','2023-09-30','2023-10-01','2023-10-02','2023-10-03','2023-10-04','2023-10-05','2023-10-06','2023-10-07','2023-10-08','2023-10-09','2023-10-10','2023-10-11','2023-10-12','2023-10-13','2023-10-14','2023-10-15','2023-10-16','2023-10-17','2023-10-18','2023-10-19','2023-10-20','2023-10-21','2023-10-22','2023-10-23','2023-10-24','2023-10-25','2023-10-26','2023-10-27','2023-10-28','2023-10-29','2023-10-30','2023-10-31']
sales = [935167, 781900, 599600,731100 ,770600 ,843300 ,934100 ,979800 ,1133900 ,437296 ,821500 ,997100 ,639200 ,982700 ,855700 ,922500 ,546200 ,873400 ,869760 ,691900 ,1110200 ,1027300 ,993400 ,592400 ,889700 ,933800,998100 ,486000 ,0 ,293400 ,0 ,581400 ,473900 ,600600 ,995600 ,1148900 ,939700 ,457200 ,566200 ,1018300 ,956800 ,769900 ,942800 ,823100 ,458100 ,789500 ,862900 ,955200 ,1003075 ,990500 ,911900 ,478800 ,968100 ,1093300 ,1036500 ,967400 ,901400 ,982800 ,340600 ,847700 ,879500]
df = pd.DataFrame({'ds' : time, 'y' : sales})

# %%
df['ds'] = pd.to_datetime(df['ds'], errors = 'coerce')

# %%
model = Prophet()

model.fit(df)
# Out:
# 16:25:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:25:27 - cmdstanpy - INFO - Chain [1] done processing

# %%
df.plot()
plt.show()

# %%
start_date='20231101'
end_date='20231108'
future_7days=pd.date_range(start=start_date, end=end_date, freq='D')
future_7days = pd.DataFrame(future_7days, columns = ['ds'])
future_7days['ds']= pd.to_datetime(future_7days['ds'])

# %%
forecast = model.predict(future_7days) # 향후 11월 1일부터 11월 8일까지의 예측, dataFrame에 저장

# %%
model.plot(forecast)
plt.show()

# %%
f_date = forecast['ds'] #날짜
f_min = forecast['yhat_lower'] #최솟값
f_max = forecast['yhat_upper'] #최댓값
f_mean = forecast['yhat'] #평균값

# %%
forecast
# Out:
#           ds          trend     yhat_lower    yhat_upper    trend_lower  \
# 0 2023-11-01  815530.770446  599092.354369  1.125175e+06  815530.765738
# 1 2023-11-02  816146.949125  651224.810799  1.169969e+06  816146.931143
# 2 2023-11-03  816763.127805  616881.566347  1.143957e+06  816763.088218
# 3 2023-11-04  817379.306485  629923.962207  1.144301e+06  817379.243978
# 4 2023-11-05  817995.485164  213561.359012  7.134139e+05  817995.394751
# 5 2023-11-06  818611.663844  542119.800087  1.066429e+06  818611.545592
# 6 2023-11-07  819227.842524  671302.138374  1.150506e+06  819227.689518
# 7 2023-11-08  819844.021203  592311.182289  1.119225e+06  819843.835017
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  815530.775880    44234.837039          44234.837039          44234.837039
# 1  816146.967137   109412.619251         109412.619251         109412.619251
# 2  816763.165937    69535.615179          69535.615179          69535.615179
# 3  817379.365066    69038.047116          69038.047116          69038.047116
# 4  817995.567250  -360989.077214        -360989.077214        -360989.077214
# 5  818611.772649   -11361.153868         -11361.153868         -11361.153868
# 6  819227.976386    80129.112499          80129.112499          80129.112499
# 7  819844.188621    44234.837039          44234.837039          44234.837039
#
#           weekly   weekly_lower   weekly_upper  multiplicative_terms  \
# 0   44234.837039   44234.837039   44234.837039                   0.0
# 1  109412.619251  109412.619251  109412.619251                   0.0
# 2   69535.615179   69535.615179   69535.615179                   0.0
# 3   69038.047116   69038.047116   69038.047116                   0.0
# 4 -360989.077214 -360989.077214 -360989.077214                   0.0
# 5  -11361.153868  -11361.153868  -11361.153868                   0.0
# 6   80129.112499   80129.112499   80129.112499                   0.0
# 7   44234.837039   44234.837039   44234.837039                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper           yhat
# 0                         0.0                         0.0  859765.607485
# 1                         0.0                         0.0  925559.568376
# 2                         0.0                         0.0  886298.742984
# 3                         0.0                         0.0  886417.353600
# 4                         0.0                         0.0  457006.407950
# 5                         0.0                         0.0  807250.509976
# 6                         0.0                         0.0  899356.955023
# 7                         0.0                         0.0  864078.858243

# %%
f_mean
# Out:
# 0    859765.607485
# 1    925559.568376
# 2    886298.742984
# 3    886417.353600
# 4    457006.407950
# 5    807250.509976
# 6    899356.955023
# 7    864078.858243
# Name: yhat, dtype: float64

# %%
file = pd.read_csv("11.csv")

# %%
file.rename(columns = {"Unnamed: 2" : "True_salary"}, inplace = True)

# %%
file = file.iloc[0:9,:3]

# %%
file
# Out:
#            ds          y  count
# 0  2023-11-01  1,076,340    171
# 1  2023-11-02  1,076,834    171
# 2  2023-11-03    874,400    139
# 3  2023-11-04          0      0
# 4  2023-11-05          0      0
# 5  2023-11-06    729,200    117
# 6  2023-11-07  1,076,170    164
# 7  2023-11-08    969,454    130
# 8  2023-11-09    987,772    143

# %%
file['y']
# Out:
# 0    1,076,340
# 1    1,076,834
# 2      874,400
# 3            0
# 4            0
# 5      729,200
# 6    1,076,170
# 7      969,454
# 8      987,772
# Name: y, dtype: object

# %%
tr = file['y']

# %%
tr = tr.drop(0)

# %%
tr = tr.str.replace(',', '').astype('int64')

# %%
tr.reset_index()
tr = tr.reset_index(drop = True)
tr
# Out:
# 0    1076834
# 1     874400
# 2          0
# 3          0
# 4     729200
# 5    1076170
# 6     969454
# 7     987772
# Name: y, dtype: int64

# %%
day = file['y'].iloc[1:9]
day = day.reset_index(drop = True)
day
# Out:
# 0    1,076,834
# 1      874,400
# 2            0
# 3            0
# 4      729,200
# 5    1,076,170
# 6      969,454
# 7      987,772
# Name: y, dtype: object

# %%
error = pd.DataFrame({'날짜' : day,'실제 주간 매출' : tr, '예상 매출액' : f_mean.round(0), '오차율' : diff})

# %%
error
# Out:
#           날짜  실제 주간 매출    예상 매출액     오차율
# 0  1,076,834   1076834  859766.0  25.25%
# 1    874,400    874400  925560.0   5.53%
# 2          0         0  886299.0  100.0%
# 3          0         0  886417.0  100.0%
# 4    729,200    729200  457006.0  59.56%
# 5  1,076,170   1076170  807251.0  33.31%
# 6    969,454    969454  899357.0   7.79%
# 7    987,772    987772  864079.0  14.32%

# %%
diff = ((tr - f_mean)/f_mean).mul(100).round(2).abs()
diff
# Out:
# 0     25.25
# 1      5.53
# 2    100.00
# 3    100.00
# 4     59.56
# 5     33.31
# 6      7.79
# 7     14.32
# dtype: float64

# %%
diff = diff.astype('str')

# %%
diff = diff + '%'

# %%
diff
# Out:
# 0    25.25%
# 1     5.53%
# 2    100.0%
# 3    100.0%
# 4    59.56%
# 5    33.31%
# 6     7.79%
# 7    14.32%
# dtype: object

# %%
error
# Out:
#           날짜  실제 주간 매출    예상 매출액     오차율
# 0  1,076,834   1076834  859766.0  25.25%
# 1    874,400    874400  925560.0   5.53%
# 2          0         0  886299.0  100.0%
# 3          0         0  886417.0  100.0%
# 4    729,200    729200  457006.0  59.56%
# 5  1,076,170   1076170  807251.0  33.31%
# 6    969,454    969454  899357.0   7.79%
# 7    987,772    987772  864079.0  14.32%
